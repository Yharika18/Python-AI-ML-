# %% [markdown]
# ![image.png](attachment:72b2924c-6747-406e-ae2a-9193d311e348.png)

# %% [markdown]
# ![image.png](attachment:f4ec420f-5505-4ffc-a0e3-581f0eab68c4.png)

# %% [markdown]
# - because of greedy we lead to overfitting-- to get train when tree is growing so it is complext so it might miss some datapoints so because of this model might be overfit
# - when you have huge variance in data tree size increase complex increase and depper the tree and then overfititng caused
# -  beacuse of this greedy approch is risky in decision tree

# %% [markdown]
# ![image.png](attachment:e0ae1912-496d-44bc-9ef5-8de10eae4875.png)
#
#
# ![image.png](attachment:dab8cd82-87b1-41e4-abfa-b60f14214a43.png)

# %% [markdown]
# - Entropy, information gain, gini impurity are used on what bases does the tree split should happen
# - entropy - measure of randomness in the data. it gives impurity present in dataset.
# ![image.png](attachment:b2ae595b-0673-401b-9d77-11559f69bce3.png)

# %% [markdown]
# ![image.png](attachment:53385934-8a04-4fa8-b958-1dacd1153e2d.png)

# %% [markdown]
# ![image.png](attachment:df65ad9a-266d-4e2c-b2c0-fb87fb03b311.png)

# %% [markdown]
# Entropy and Ginni impurity --  in gigni we calculated impurity by propbabilities where in entropy impurity is calculated by log
# gini -- less cost
# Entropy -- more cost compared to gini
# - In gini we select the root node as which value is less while clalucating probabilities
# - In entropy and information gain we select the root node we caluclate the entropy which is information gain and entropy which is log and value is less

# %% [markdown]
# Based on these entropy and ginni and information gain we  we got different models
#
# ![image.png](attachment:cb36a8d4-b7d3-488d-93cd-79f0e4da8db0.png)

# %% [markdown]
# ![image.png](attachment:d4d88c14-f6d3-4ef5-9037-68bfd2387de3.png)

# %% [markdown]
# Holdout- dived 2 data set like test and train -- evaluation is like high variance  because everythime decision changes
# ![image.png](attachment:bb903974-b803-4e0e-a03f-f4a86104eb4a.png)

# %% [markdown]
# ![image.png](attachment:44c89f7c-bb2a-4a03-ab67-b7d545fbc456.png)

# %% [markdown]
# ![image.png](attachment:318faec1-7423-4388-8de3-c3f37b6d8d54.png)

# %% [markdown]
# # stratified cross validation
#
# # Hyperparameters
# ![image.png](attachment:2454db6b-da7b-41f3-ab4e-c55caf3c9614.png)
#
# ![image.png](attachment:6644b30a-caf3-4bd0-8aea-d756697189bc.png)

# %% [markdown]
# disadvantages  of descion tree
# - more cost
# - overfitting because of high variance
# -  beacuse of decision tree we use randon forest
#
# - To overcome overfittibg we enseble techniques called bagging and boosting
# - Bagging technique- we built multiple decision trees and they are connected in parrel what ever we have data we split randomly and feed it to the model we get output for different models so like if they give yes no o/p which ever have best vote then we will pic that as final
# - if we have 3,4,5,6 then we take avaegrage and final that model as o/p final
# - - bagging we have only Random forest
# - - still there is a problem with bagging when we get error in different model which are parllel we need to fix it is more cost computation bcz need to fix parllely
#   -  so boosing techniques coms to resolve this issue we connect the decision trees in series
#   -  we have adaptive boosting
#   -  gradient boosting
#   -  extereme gradient boosting

# %% [markdown]
# # What dis advantage of connecting in parllel
# # Boosting
# # boosting pros and cons
# # then several algorithms which we use  ada boost
# - take the example for adaboost we calculate gini indexs
# ![image.png](attachment:7285d1fa-ce7d-475a-9cfb-0accc31c1189.png)
#
# ![image.png](attachment:3747ba67-d348-4138-9a2c-6434384e29f9.png)
#
# - disadvantage of ada why mved to gradient boosting
#
#   ![image.png](attachment:90ba333f-36d5-48ac-8fb6-5ad5d61e4f60.png)
#
# - gradient boosting - how it does what ada doesn't do
# -
#
# final resumt i.e 1st prediction+ learning rate * 1st residual + learning rate * 2nd residual + and so on
# -- less computation
# -- better handling of variance
#
# - XG Boost(Extreme gradient boosting)-- in this grading boosting what it odes alogng with that we add regularizations
# advantage of Xg BOOst
# - calculate double derivate -- which handle loss and variance  and also handle sparcity(where we have more no of 0's in the data) so it also handles overfitting anf gradient descent
#
# - we have a cataboost -- it builts for catgeorical data-- no need to convert numerical we can diarectly send caterogical data internally it handle so this is advantage
#
# -  light GBM -- it used for huge volume of data -- it does optimization is
# ![image.png](attachment:39c3f76a-f385-4f6a-9236-ec6bd715d8c8.png)
#
# in this 2nd diagram it goes through impurity based not in level wise
#
#
# -- search google  light GBM Vs XG Boost -- go to greek to greek site

# %% [markdown]
# -- explain KNN(k neareast negihbors)
# Eculedian diatsnace  and manhattew distance  and  cosine similarity
# ![image.png](attachment:9cccb098-c3d2-418b-91f4-74a6f6e1d1da.png)

# %% [markdown]
# # SVM -
# - used medium site for this lecture
#
# - ![image.png](attachment:662d83fd-b846-41a6-8c2e-612a0b14ec16.png)
#
# - we going to best best descion boundary called as hyperplane
#
# -  the points which are closer to the plane those are called as support vectors
# -  deciding hyper which have maximum margin from point to the hyperplane
#    which maintain high margin then
#
# - with non linear seperable data we use plane  -- go through the medium website
