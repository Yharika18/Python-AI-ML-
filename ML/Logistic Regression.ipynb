# %% [markdown]
# - up sampling
# - down sampling--- disadvantages -- lose important patterns -- so we canot do this when it is imbalance so we should upsample and do data argumentation but don't decrease

# %% [markdown]
# # Classification
# - Classification is a supervised machine learning technique used to predict labels or categories from input data. It assigns each data point to a predefined class based on learned patterns.
#
# ![image.png](attachment:881f5cd6-d752-4edf-8c1b-dd6bdc546d51.png)

# %% [markdown]
# # Logistic Regression
# Logistic Regression is a supervised machine learning algorithm used for classification problems. Unlike linear regression, which predicts continuous values it predicts the probability that an input belongs to a specific class.
#
# - Logistic Regression--> y=mx+c -- to get the discrete value we use to apply sigmoid , functions
#
# - sigmoid function what it does is  o/p whatever values you are getting all these values are compressed between 0 and 1

# %% [markdown]
# # sigmoid function
#
# 1. The sigmoid function is a key component of Logistic Regression that converts the model's raw output into a probability value between 0 and 1.
#
# 2. This function takes any real number and maps it into the range 0 to 1 forming an "S" shaped curve called the sigmoid curve or logistic curve. Because probabilities must lie between 0 and 1, the sigmoid function is perfect for this purpose.
#
# 3. In logistic regression, we use a threshold value usually 0.5 to decide the class la
#    - If the sigmoid output is same or above the threshold, the input is classified as Class 1.
#    - If it is below the threshold, the input is classified as Class 0.
# lass 0.

# %% [markdown]
# In linear we call best fit line but here we call boundary line
# - the boundary line split the data into 2 classes
# - the line equation is still y=mx+c -- to split dta we apply sigmoid for y=mx+c we apply sigmoid
# - if we have 0 as cancer and 1- no cancer if we get values as 0.25 and 0.45 i cann't say cancer or no cnacer in this we use threshold
# -- threshold -- we set this threshold value based on this value we will split
# --- we will decide threshold value by ROC curve
#
# - Softmax function -- here sigmoid makes 0-1 for binary classification but if i have multi class for this i will add softmax function
# softmax function does is like total sum of probabilities of classes we have this total sum =1
# eg: dog, cat, monkey, donkey -> 0.1,0.3,0.5,0.1--> i will sum all the equl to 1 so here monkey has highest so i can say monkey has highest

# %% [markdown]
# # Evaluation metrics
# Evaluating the logistic regression model helps assess its performance and ensure it generalizes well to new, unseen data.
#
#
# ![image.png](attachment:d68038dc-c004-4cc6-8ada-2676e8cc2980.png)s
#
# it is harmonic mean of precision and recall -- it will give the actual value how the model is performing not by consedering accuracy
# -  specificity / ture negative rate-- actual is true and predected is negative
# -

# %% [markdown]
# -  Recall/sensitivity -- we need to tell o/p how much our model is able to remember and recollect correctly
#
# -  precision-- total positives from that how many are actual positive
# -  Problem : - acurracy is high and recall and precision are less it not able to perform well with recall and precision
# -  accuracy is no the metric to use for evaluating the model in this case
# -  the we get f1 score-- it is harmonic mean of precision and recall -- it will give the actual value how the model is performing not by consedering accuracy
# -  specificity / ture negative rate-- actual is true and predected is negative

# %% [markdown]
# # ROC(Receiver Operator Characteristic)
# - ![image.png](attachment:e126ee6f-f78b-4a27-adf1-10a79941aac7.png)

# %% [markdown]
# - Based on threshhold values we get this classify but there is a missclassification
#
#
#
# ![image.png](attachment:b67c32ed-a919-4287-b68c-4ec757f5f4fb.png)

# %% [markdown]
#  - now draw roc and then change threshold and plot in roc
#
# ![image.png](attachment:c9bb5388-9be4-4214-9eee-cdd1ebb9aef4.png)

# %% [markdown]
# where at one point the points are constant that point we fix threshold value where TP=FP rate in graph where green circle pointed
# - after some time fp rate becomes zero

# %% [markdown]
# # AUC(Area Under Curve)

# %% [markdown]
# ![image.png](attachment:3050cf84-16f3-4124-a74d-ca292a7a2862.png)

# %% [markdown]
# - we plot the curve for other model when we use models to compre ehich model is working well
# -- based on below snippet info we pick which model is good
#
#   ![image.png](attachment:9cc972a4-55d5-4b86-bd6d-1e3324af41ad.png)

# %% [markdown]
# # Precision-Revall Curve
#
# - when we have outliers the roc and auc curves get impacted  then we calculate Precison and recall and then we plot and then we use threshold value

# %% [markdown]
# ![image.png](attachment:f272a53b-b3a0-4829-ab41-a96442bcbecf.png)
