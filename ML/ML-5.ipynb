# %% [markdown]
# # Unsupervised Learning
#
# without labeling the data we give it to model to find the pattern

# %% [markdown]
# # Clustering
# - The goal is to determine the intrinsic groups in unlabeled data.
#
# ### Applications
# - Customer segmentation
# - for data analysis
# - as a dimensionality reduction technique -PCA
# - for anomaly detection(outlier detection)
# - for semi supervised learning
# - for search engines- like ecommerce sites for recommondation platforms
# - for segment an image

# %% [markdown]
# ### Approches for clustering
#
# -- How the clustures are formed
# 2 ways
# - Agglomertative clustering(Aggregating)- 1st consider all points as indiviual cluster ad
#
# ![image.png](attachment:59c6c211-f35e-454b-8523-87f028c1adae.png)
#
#   ![image.png](attachment:8e9307c5-27a3-44bf-bc99-42dab59f8090.png)
#
# - Divisive

# %% [markdown]
# # Kmeans clustering
# -- intial data
# - we intialize k value
# - then calucate the centroid to all the data points
# - from this we decide which point belongs to which centorid and then we recalcuate the centroid then centroid point moved then new centroid are formed from this new centroid we calcluate
# - finally there is no change of centroid moving with data points then we stop
#   ![image.png](attachment:886d253d-4047-43bd-b3f1-41c5ca768457.png)

# %% [markdown]
# ### How to select K values
# - one way is based on the requirement you need and then
# - random intilization - we assign check the performance and then we reassign
# the other method is
# - Elbow-method - relationship b/w within -cluster sum of squared dustances and the no.of clusters.It is oberseved first with an increase in the no.of clusters
#
# ![image.png](attachment:0664bdf5-5c89-4376-beb8-3b5ceb2b94db.png)
#
#
# Disadvantage of k-means is we need to pre-enter the no.of clusters(K)

# %% [markdown]
# ### Hierarchial Clustering
# - It is a Agglomertative clustering
# - Dendrogram
#
# ![image.png](attachment:05f30062-2425-4369-97c4-6159dde79b94.png)
#
#
# - Based on dendogram we can decide clusters when we draw horizontal line with touches dendogram then it will give as many no.of clusters

# %% [markdown]
# ![image.png](attachment:327da075-f38c-4015-96d3-275a2138f942.png)

# %% [markdown]
# # DBSCAN
#
# - It defines clusters as continous regions of high density
# - Epslon - Also called as eps. this is the distance till which we look for neighbouring points
# -  Min_Points
#   -  Core points - If the no.of points insdie the eps radius of a point is greater than or equal to min_points then it is called core point
#   -  Border Points
#   -  Noise-  A point which is neither a core nor a border point is a noise point
#
#
# ![image.png](attachment:f00d83be-02b4-4574-8592-376560b2b7a3.png)

# %% [markdown]
# ![image.png](attachment:61c1219f-2a12-40a0-9b34-a0bc51341ca6.png)

# %% [markdown]
# # Clustering Metric in Machine learning
# - greeks for greeks - silhouette score
# ![image.png](attachment:242ed852-0ede-4238-89db-c79068fe9cc0.png)

# %% [markdown]
# # Evaluation Of Clustering
#
# ![image.png](attachment:60f3e6fa-6e8d-4d46-b38f-2adfaaf9478e.png)

# %% [markdown]
# - internal Measures
#    - cohesion
#    - seperation
