# %% [markdown]
# # Supervised Models
# - set and label the data and you train the model and it start the learning the pattern and later identify the pattern
# - linear, logistic, random forest, boosting techniques, decision trees
# # Unsupervised Models
# - dont label data directly give the data to the model them model tries to classify
# - clutsering- kmeans,dbscan,hierarchial
# # semi Supervised Models
# - 100 samples to train 40 is labeled and 60 unlabeld like 80 labeled or 20 unlabed
# # Reinforcement Models
# - it work based on reward and penality mechanism.

# %% [markdown]
# ![image.png](attachment:59b272d1-7869-4d71-8b39-1e2af1318854.png)![image.png](attachment:7ca9e66c-a8f8-4479-9a8b-7e65f1b8c3e3.png)

# %% [markdown]
# # Supervised Models
# 1. Regression
# 2. Classifciation

# %% [markdown]
# # Regression
# trying to predict the continous values
# - like pirce of land, height and weight of person etc
# # classification
# - trying to predict values like labels
# - diabetic or not, cancer or not
#   1. binary - 0 or 1
#   2. multi -label
#   3. multi class

# %%
# Life cycle diagram for machine learning model

# %% [markdown]
# # Regression
# - Regression is predicting label (or dependent variable) based in the features(independent variable). regression is used for tiemseries modelling

# %% [markdown]
# # Linear Regression
# - used to predict the continous values/dicrete independent variables
# - A linear regression model predicts the dependent variable using a regression line based on the independent variables

# %% [markdown]
# # BEST FIT LINE-- LIKE RESIDUAL AND ERROR CONCEPT
# - GOAL TO REDUCE RESIDUAL ERROR RATE-- ACTUAL VALUE - PREDICTED VALUE

# %%
# Ordinary least square(OLS)-- to calculate MNS
#2nd approach is gradient  descent -- local minima,maxima and global minima and maxima concepts
# -- cost function and learning rate-- gradient descent is one of the loss function used to solve these gradient weights

# %%
# MAE(Mean absolute error)
# RMSE(Root Mean squared Error)
# R- squared-- R2 Satistics -- how much of our data it is being explained by our model
#--Rsquare formula=TSS-RSS/(TSS)
''' RSS- residual sum of square
TSS- total sum of square
ess- Explained sum of square'''
# - Adjusted Rsquare
# Out:
# ' RSS- residual sum of square\nTSS- total sum of square\ness- Explained sum of square'

# %%
# trained
# overfitting
# underfitting
# -- class imbalance we get overfit and underfit
# multi colinearity
# regularizations

# %%
# Because of adjusted r2 value we are getting bcz of unimportant or unwanted features bcz of this model is getting overfit to handel  this we do regularization

# %%
# multi colinarity
# example of heat map
# variance inflation factor

# %% [markdown]
# # 17th
#
# # Bias variance trade-off -
# Bias- is a measure of the polarity of the results
# varinace- it is a measure of degree of the spread of the predicted results
# low bais and low variance , low bias and high variation- diagram
# high bias and high variance--- diagram
# high variance- overfit
# low variance- undefit
# - Bia variance tradeoff-- low bias andlow variance -- diagram graph

# %% [markdown]
# Regularization -- to train some data there is a chnace the model get overfit wherere regularization helps
# helps to sort overfitting problem by restricting degree of freedom of a given equation

# %% [markdown]
# -- lambda is adding this lambda is a shrinkage penality this is addes to cost function to regularize the model
# LASSO-- overfitting -- modules of beta -- we eleminate features
# Ridge(L2)-- modules of beta square

# %% [markdown]
# --Why use Regularization
# -- difference btwn rdige and lasso
# ---Elastic net -- combination of ridge and lasso

# %% [markdown]
# # import

# %% [markdown]
# data= pd.read_sv('advertising.csv')
# data.head()
#
# ---- what are the features:
# Tv
# rADIO
# newspaper-- column names
#
# ------ what is response?
# Sales: sales of single product
# -- check null
# -- plot scatter plot -- it show how data isincreasin g- like input increases then output also increases
# --- ask questions-- see snippet
#
# -- simple linear regression we use to solve above question problem
# -- split data into train and test
# -- take only 1 i/p and o/p
# --- predicted the model
#
# -- output(diagram)
# --- we check r square we are not able to compare with 1 feature -- snippet
#
# -- Adjusted R2
# --  aaded more features and then all above and then applied regularizations
# -- snippet
# -- snippet

# %% [markdown]
# # POLYNOMIAL REgression
# ----lineal regression with polynomial degree 2
# -- if degree increarse how graph changes

# %% [markdown]
# # check if problem statement is regression check it is linear or multiple or polynomial
