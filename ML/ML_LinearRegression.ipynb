# %% [markdown]
# # Machine learning
# - It is a subset of AI
# - It provides statistic tools to analyze data, visualize the data and predict the forecasting

# %% [markdown]
# ### Machine learning algorithms
# 1. Supervised Machine learning
# 2. Unsupervised Machine learning
# 3. semi superv
# 4. ised -100 samples to train 40 is labeled and 60 unlabeld like 80 labeled or 20
# 5.  reinforcement-it work based on reward and penality mechanism.

# %% [markdown]
# ![image.png](attachment:c420ac01-8c6d-49b5-a788-04618fb56782.png)

# %% [markdown]
# # 1. Supervised Machine learning
# In supervised machine learning the model is trained on labeled data and pre-processed to predict outcome and classify data accurately
#
# - Independent features: Input we are training ( any no.of independent features)
# - Dependent feature:  output ( 1 dependent feature)

# %% [markdown]
# # Types Of Supervised Learning
# 1. Regression - Where the output is continous variables -Eg: height and weight ,stock prices, house prices
# 2. Classification- where the output is categorical variable - Eg: spam vs non spam, diabetic vs not diabetic
# - 2 output -binary classification
# - more than 2 categories it is multi classs classification-

# %% [markdown]
# # Supervised
# 1. Linear Regression
# 2. Ridge & Lasso Regression
# 3. Logistic Regression
# 4. Decision Trees
# 5. Random Forest
# 6. AdaBoost
# 7. Gradient Bossting
# 8. XG boost
# 9. Navie Baye's
# 10. SVM
# 11. KNN

# %% [markdown]
# # 2. Unsupervised Machine learning
# It is atype of ML where the model works without labelled data.It learns patterns on its own by grouping similar data points or finding hidden structures without any human intervention.
#
# - No dependent variable in unsupervised learning

# %% [markdown]
# # Types Of Unsupervised Learning
# 1. Clustering - Based on data we try to find similar groups like clusters
# 2. Dimensionality reduction - Using this we are going to reduce the dimensions by using PCA,LDA

# %% [markdown]
# # Unsupervised
# 1. Kmeans
# 2. DB Scan
# 3. Hierarcheal
# 4. K Nearest Neighbor
# 5. PCA
# 6. LDA

# %% [markdown]
# # Linear Regression
# - used to predict the continous values/dicrete independent variables
# -
# A linear regression model predicts the dependent variable using a regression line based on the independent variable
# - Equation of straight line is y=mx+c
# - Intercept - at what point you are meeting the y-axis
# - The main of linear regression is like to create a best fit line such a way that the distance between the data points we have and preditced points should be lesss

# %% [markdown]
# # Cost Function
# - we need to start at one point and randomly check which points we can get best fit line for this purpose we create a cost function
# -  To get best fit line we need to update slope and intercept everytime
# - when we find the ditsance and sum up those then we need to get minimal
#
# - cost function = 1/2m sum from i=1 to m  (y^ - y)2
# - here we are using 2m because wehn ever we use derivated to get m we use 2m here

# %% [markdown]
# - if intercept( c=0) then we can say it passes through origin the equation is y=mx when passes through origin
# - Example:  we have data points as(1,1) ,(2,2), (3,3)-- actual data points
# if m=1 then cost function will become 1/2m(sum of i=1 to m[(1-1)2 + (2-2)2 +(3-3)2])=0
# - if slope i.e m=0.5  in y=mx+c if m=0.5*1=0.5 and m=0.5*2= 1 and m=0.5*3=1.5 these are predicted points
# then cost function will become 1/2m(sum of i=1 to m[(0.5-1)2 + (1-2)2 +(1.5-3)2])=~0.58
# - if slope i.e m=0 them y=mx+c we will get all as 0
# then cost function  1/2m(sum of i=1 to m[(0-1)2 + (0-2)2 +(0-3)2])=1/6(1+4+9)=~ 2.3
# - when we join all the points like that we get curve called gradient descent in this where my point is meeting x-axis that is the global
# - here above at 1 m=1 that points come at global minima so that is the best fit line when m=1
#
#   ![image.png](attachment:282d486f-4b31-4a9d-808b-1b77ad338d9f.png)
#
#    ![image.png](attachment:5ff3ad20-317a-4fe8-b5f1-6b011949d2f9.png)

# %% [markdown]
# # Gradient Descent
# - used to minimize the error of a machine learning model by updating parameters in the direction of decreasing loss.

# %% [markdown]
# # Convergence Algorithm
# - Here we are randomly selecting slope i.e m values and trying to reach the gloabla minima for this we do by using One convergence algorithm
# - Convergence algorithm basically says that
#
#   ![image.png](attachment:a924b542-99d1-4ea5-922b-8b0a1d49addc.png)

# %% [markdown]
# - After performing above operation we should be able to reach the global minima to reach we follow below diaram process
# -
# ![image.png](attachment:4165a628-6c63-4928-81b2-e2743b321b14.png)
#
#
#
#   ![image.png](attachment:4376b767-fb5f-4bf2-aed9-71468d8db1cd.png)

# %% [markdown]
# # Learning Rate(ALPHA)
#
#  By using this it helps to move slope to reach global minima
#  if learning rate is not too small value aslo small value what speed we should come to global minima
#  if learning rate is big value this updation of tita1 is like jumping it will never reach global minima
#
#
#  ![image.png](attachment:410bd222-9084-4c52-b6d1-a504ec6654ee.png)

# %% [markdown]
# # Types Regression Metrics
# 1. Mean Absolute Error (MAE) - measures the average absolute difference between actual and predicted values
#    - It treats all errors equally, regardless of their direction and provides results in the same unit as the target variable, making it easy to interpret.
#
#
#      ![image.png](attachment:207b8f05-b2a6-440d-a996-7e69f31f5496.png)
#
# 2.  Mean Squared Error (MSE) - alculates the average of squared differences between actual and predicted values.
#    -  By squaring errors, it penalizes larger mistakes more strongly, making it sensitive to outliers.
#
#
#       ![image.png](attachment:e56ffc13-0305-4b7d-8010-ee67070443b4.png)
#
# 3. Root Mean Squared Error (RMSE) - It  is the square root of MSE
#    - It maintains the strong penalty for large errors while converting the result back to the original unit of the target variable, improving interpretability.
#
#       ![image.png](attachment:8960c47c-35ec-486c-9922-9cfa3863e185.png)
#
# 4.  R-squared (R² Score) - It represents the proportion of variance in the target variable that is explained by the regression model
#    - It provides insight into how well the model captures underlying data patterns.
#
#      ![image.png](attachment:8efb473d-bc1a-459a-90df-c91f1641d510.png)

# %% [markdown]
# - In R2 if i keep on adding features and even they are no where correlated my R2 values increases. Inorder not to impact the model and prevent we use adjusted R2
#
# ![image.png](attachment:1f0751b7-9d74-466f-96c6-99d2bb425786.png)

# %% [markdown]
# # Adjusted R2
#
# - for my r2  percent my adjusted r2 is less and if we increase features the my r2 increases but my r2 adjusted decreases than earlier one
# - where p= predicted values
#
# ![image.png](attachment:f8ca25cc-4ae9-450e-9ddb-319d1cd7a037.png)

# %% [markdown]
# - If the features are highly correlated R2 values increases rapidly if there is less correlated there will be less increase

# %% [markdown]
# # Overfitting

# %% [markdown]
# - we will draw best fit line based on our data when we get new data and predict those values the predicted and new data points have large distance then it is called overfitting
# - model accuracy- Good on Training Data --> Low Bias
# - model accuracy-bad on Test data --> High Variance
#
# ![image.png](attachment:82db1ea8-2abf-4170-a5f8-910c0218f983.png)

# %% [markdown]
# # Underfitting

# %% [markdown]
# - model accuracy -bad  on Training data - High Bias
# - model accuracy - bad on Test Data- High Variance

# %% [markdown]
# ![image.png](attachment:2d307222-8bcf-4d56-985f-77dbbc926930.png)

# %% [markdown]
# ![image.png](attachment:fa21fba3-445a-4b9e-80c2-c908b372965a.png)

# %% [markdown]
# # Multi Collinearity
# Multicollinearity happens when two or more predictor(independent) variables in a model are closely related to each other.
#
# - we get issue with model performance
# -  to solve a part from dependent feature  which all features are highly corelated like mor than 90% we will write block of code take those feature and drop that code this work if we have small feature
# -   for more features we have we will solve we take those features and appply ridge or lasso regrresion
#
#   ![image.png](attachment:1e792e66-1eec-4609-b12b-47c5953c93b6.png)

# %% [markdown]
# # Bias -Variance TradeOff

# %% [markdown]
# - Bias: Error caused by overly simple assumptions in the model, which may lead to underfitting.
# - Variance: Error caused by the model being too sensitive to training data, which may lead to overfitting
# - Bia variance tradeoff-- low bias and low variance
# -low bias, high variance- overfitting
# - high bias, high variance- underfitting
# ![image.png](attachment:f9e69f26-51f7-4cda-8867-251b58303307.png)

# %% [markdown]
# ![image.png](attachment:f8b6de79-e2ff-4830-bcb9-b60f60de2b97.png)

# %% [markdown]
# # Regularization
# - Is used to train some data there is a chance the model get overfit where regularization helps to sort overfitting problem by restricting degree of freedom of a given equation

# %% [markdown]
# # Ridge Regression
# - Ridge Regression is a version of linear regression that adds an L2 penalty to control large coefficient values. While Linear Regression only minimizes prediction error, it can become unstable when features are highly correlated.
# - Ridge solves this by shrinking coefficients making the model more stable and reducing overfitting

# %% [markdown]
# # Lasso Regression
# - Lasso Regression (Least Absolute Shrinkage and Selection Operator) is a linear regression technique with L1 regularization that improves model generalization by adding a penalty.
# -  This penalty not only controls overfitting but also performs automatic feature selection by shrinking some coefficients exactly to zero, making Lasso useful in high-dimensional datasets where interpretability and sparsity are important.
# -  Uses L1 regularization to reduce overfitting
# -
# Encourages sparse models (zero coefficients
# )-
# Automatically performs feature selectio-  n
# Useful for high‑dimensional datasets

# %% [markdown]
# # Difference between Ridge and Lasso
# Ridge regression shrinks the coefficients for those predictors which contribute very less in the model but have huge weights, very close to zero. But it never makes them exactly zero. Thus, the final model will still contain all those predictors, though with less weights. This doesn't help in interpreting the model very well.
#
# - In Lasso, the L1 penalty does reduce some coefficients exactly to zero when we use a sufficiently large tuning parameter.
# - In addition to regularizing, lasso also performs feature selection.
# - Ridge regression shrinks the coefficients for those predictors which contribute very less in the model but have huge weights, very close to zero. But it never makes them exactly zero. Thus, the final model will still contain all those predictors, though with less weights.
# - This doesn't help in interpreting the model very well. This is where Lasso regression differs with Ridge regression. In Lasso, the L1 penalty does reduce some coefficients exactly to zero when we use a sufficiently large tuning parameter A. So, in addition to regularizing, lasso also performs feature selection.

# %% [markdown]
# # Why use Regularization?
#
# Regularization helps to reduce variance of the model, without substantial increase in bias. If there is variance in the model it means model won't fit well for dataset different that training data.
#
# - λ is the tuning parameter which controls bias and variance tradeoff. when value of λ increased to certain limit then it reduce variance without loosing any prperties in data.
# - But after certain limit λ model will start loosing some properties which will increase bias in the data
# -  this λ is selected using cross validation methods.
# -  cross validation is used to split the data into test and train data
# -   A set of λ is selected and cross - validation error is calculated for each value of λ and that value λ is selcted for which cross validation error is minimum

# %% [markdown]
# # Elastic Net
# - Elastic Net is middle between Ridge Regression and Lasso Regression. It is a simple mix of both Ridge and Lasso Regularization terms and can control mix ratio.

# %% [markdown]
# # Multiple LinearRegression
# - In this we include multiple features and create a model to see the relationship between those features and label column this is called multiple linear regression
#
# ![image.png](attachment:f5c6f244-2c98-4879-b9fd-687945c88a97.png)

# %% [markdown]
# # Polynomial Regression
#
# - it is used to predict a dependent variable based on the polynomial relationship with the independent variable.
#
# ![image.png](attachment:36e02fe8-004c-492a-ba7e-a278bb146252.png)
