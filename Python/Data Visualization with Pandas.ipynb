# %%
import numpy as np
import pandas as pd
import os
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
titanic_datat=pd.read_csv(r" ")
titanic_data

# %%
titanic_data.head(10)

# %%
titanic_data.tail(10)

# %%
titanic_train.dtypes

# %%
a= titanic_train.dtypes()

# %%
titanic_train[a].describe()

# %%
titanic_train.describe()

# %%
titanic_train[['Name','Sex','Age']]

# %%
sorted(titanic_train['Name'])[5:30:2]

# %%
titanic_train["Name"].describe()

# %%
titanic_train[['Ticket']][4:9:2]

# %%
titanic_train["Ticket"].describe()

# %%
titanic_train.columns

# %%
# addd additional info 
titanic_train["Hari"]="sddffs"
titanic_train.head()

# %%
# check first 15 records
titanic_train["Harika"][0:15]

# %%
titanic_train.dtypes

# %%
# data of particualr column
titanic_train["Survived"] # keep in project

# %%
new_pclass= pd.categorical(titanic_train["Pclass"])
new_pclass

# %%
# check unique cabins
titanic_train["cabin"].unique()

# %%
import numpy as np
char_Cabin= titanic_train["cabin"].astype(str)# convert data tp str
new_cabin = [cabin[0] for cabin in char_cabin # Take 1st letter

new_cabin =pd.categorical(new_Cabin)
new_Cabin

# %%
titanic_train["cabin"]= new_Cabin
titanic_train.head()

# %%
titanic_train["Age"].isnull()

# %%
np.where(titanic_train["cabin"]...........

# %%
# add new column with existing 2 columns

# %%
# iloc,loc- to filter the data using pandas
# iloc- index based filtering
# loc- lable based indexing

# %%
# create sample set and have 3 labels and have data for labels and create dictionaries

# %%
# pd.series( data,index=labels)

# %%
# pd.series( labels,index =data)

# %%
#  create a simple dictioneries with key -pair  and convert dict into data frame 
pd.dataframe

# %%
# create series1 and series2  to do slicing
ser1[0:3:2]

# %%
# do indexing also for above series

# %%
# do with addition adn multiply with ser1 and ser2

# %%
# create random values
from numpy,random import rand

# %%
df.iloc[0]# get data with index position
df.iloc[1,2] # get value of 1st row with 2nd column value

# %%
df.loc['c','w']# data with labels based on exact location
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 df.loc['c','w']# data with labels
#
# NameError: name 'df' is not defined

# %%
# create a new data frame and add 2 colums  or multiply

# %%
# drop- that row get drop when you need to drop specific row

# %%
# subsetting data frame-- rows to columns and columns to rows

# %%
# boolean value representation

# %%
# '&' operation

# %%
# reset index-- reset the present index and give new index

# %%
# Split()
# set index()
# zip function .... and 
# multi indexing

# %%
# remove or replcae or handle NaaN values before you train data

# %%
# missing data- replace mean, median or text data
dropna(axis=1)-- drop values in rew i.e - entire row deleted
# droping values with min 2 Naan uisng 'Thresh' paramenter
dropna(df.dropna(axis=0,thresh=2))
# Out:
#   Cell In[16], line 2
#     dropna(axis=1)-- drop values in rew i.e - entire row deleted
#                           ^
# SyntaxError: invalid syntax

# %%
# when there is Naan we can also fill with fill value also
df.fillna(value="FILL VALUE'))
# Out:
#   Cell In[17], line 2
#     df.fillna(value="FILL VALUE'))
#                     ^
# SyntaxError: unterminated string literal (detected at line 2)

# %%
# We can also fill 'NaaN' with Mean also
df.fillna(value=df['A'].mean())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 2
#       1 # We can also fill 'NaaN' with Mean also
# ----> 2 df.fillna(value=df['A'].mean())
#
# NameError: name 'df' is not defined

# %%
# bycomp.sum()
# df.groupby()
# df.groupby().describe().transpose()
# create 3 data frame to merge data we can do concatenation(pd.concat)
# conctat at row level, conctact at column level
# merge - leftjoin ,rightjoin,innerjoin, outerfull join
# mwegw=pd.merge(left,right,how='inner',on='key')

# create a custom function to use this function in caluclation 
then appply to lambda function can create
random,lenth
