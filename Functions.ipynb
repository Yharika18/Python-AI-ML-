# %% [markdown]
# # Functions
# If a group of statements is repeatedly required then it is not recommended to write these
# statements everytime seperately .We have to define these statements as a single unit and
# we can call that unit any number of times based on our requirement without rewriting
# This unit is nothing but functi
#
# The main advantage of functions is code Reusability.
#
#
# ### Syntax:
# ###### def name_of_function(arg1,arg2):
#     '''
#      This is where the function's Document String (doc-string) goes
#     '''
#     # Do stuff here
#     #return desired resultity.

# %%
def even_odd(num):
    if num%2==0:
        print(num,"is Even Number")
    else:
        print(num,"is Odd Number")   
even_odd(10)   
even_odd(15)
# Out:
# 10 is Even Number
# 15 is Odd Number

# %%
# Using Return it return that can be stored as a variable or used in whatever manner a user wants

def add_num(num1,num2):
    return(num1+num2)

print(add_num(5,6))


# return using
def add(x,y):
    return x+y   
result=add(10,20)   
print("The sum is",result)   
print("The sum is",add(100,200))
# Out:
# 11
# The sum is 30
# The sum is 300

# %%
def func_with_print():
    print("Hello")
def func_with_return():
    return "Hello"
# 
a=func_with_print()
b=func_with_return()
print(a)
print(b)
# Out:
# Hello
# None
# Hello

# %% [markdown]
# def is_prime(num):
#     for n in range(2,num):
#         if num% n==0:
#             print('not prime')
#     else: # if never mod zero, then prime
#         print('Prime')
#
# is_prime(5)

# %% [markdown]
# # Iterartors & Generator
# What is a Generator?
# A generator is a special type of iterator that is written like a function but uses the yield keyword instead of return.
#
# It pauses when it yields, and resumes from where it left off.
#
# It’s used to generate values on the fly, saving memory.
#
# Why yield instead of return?
# return ends the function and sends back a value.
#
# yield pauses the function and remembers its state, allowing it to res
# ume later.
# It create interatable object and using next method it going to iterarte the intturn values.

# %% [markdown]
# # Iterator
# if we call some huge value of "n", the second function will have to keep track of every single result. In our case, we only care about the previous result to generate the next one.
#
#
# ## next() and iter() built-in functions
#
# A key to fully understand generators is the next() and the iter() function.
#
# The next function allows us to access the next element in a sequence. Let's check how it works.

# %% [markdown]
# # What is an Iterator?
# An iterator is an object that allows you to iterate (loop) over a sequence like a list, tuple, etc.
#
# Any object with __iter__() and __next__() methods is an iterator.

# %%
l1="hello"
for i in range(len(l1)):
        print(l1[i])

# String object supoort iteration, but we cannot directly iterate over it as we could do with generator function. The iter() function allows us to do that
# Out:
# h
# e
# l
# l
# o

# %%
l="hello"
s=iter(l)

# %%
next(s) # return the 1st character
# Out:
# 'h'

# %%
next(s)
# Out:
# 'e'

# %%
next(s)
# Out:
# 'l'

# %%
next(s)
# Out:
# 'l'

# %%
next(s)
# Out:
# 'o'

# %%
next(s)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 next(s)
#
# StopIteration:

# %%
def simple_gen():
    for x in range(3,9):
        yield x

# Assign simple_gen 
g = simple_gen()
g
# Out:
# <generator object simple_gen at 0x0000018C42DF2260>

# %%
print(next(g))
# Out:
# 3

# %%
print(next(g))
# Out:
# 4

# %%
print(next(g))
# Out:
# 5

# %%
print(next(g))
# Out:
# 6

# %%
print(next(g))
# Out:
# 7

# %%
print(next(g))
# Out:
# 8

# %%
print(next(g))
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 print(next(g))
#
# StopIteration:

# %% [markdown]
# After yielding all the values next() caused a StopIteration error. What this error informs us that all the values have been yielded.
#
# You might be wondering that why don’t we get this error while using a for loop? The "for loop" automatically catches this error and stops calling next.

# %% [markdown]
# # Generators
#
# Generator is a function which is responsible to generate a sequence of values.
# We can write generator functions just like ordinary functions, but it uses yield keyword to
# return values.

# %%
def countdown(num):
    print("Start Countdown")
    while(num>0):
        yield num
        num=num-1
values=countdown(5) 
for x in values:
    print(x)
# Out:
# Start Countdown
# 5
# 4
# 3
# 2
# 1

# %%
def gencubes(n):
    for num in range(n):  # return regenerate from the memory but yield it doesn't regenerate
        yield num**3
gencubes(10)
# Out:
# <generator object gencubes at 0x0000018C42B77370>

# %%
for x in gencubes(9): #  Yield- it doesnt store in memory but it remember the value while iterating result 
    print(x)
# Out:
# 0
# 1
# 8
# 27
# 64
# 125
# 216
# 343
# 512

# %%
for i in "gsgfasnbj":
    print(i)
# Out:
# g
# s
# g
# f
# a
# s
# n
# b
# j

# %% [markdown]
# Generators are the best for calculating large sets of results (particularly in calculations that involve loops themselves) when we don't want to allocate memory for all of the results at the same time.

# %%
def genfibon(n):
    a=1
    b=1
    for i in range(n):
        yield a
        a,b=b,a+b
genfibon(5)
for num in genfibon(8):
    print(num)
# Out:
# 1
# 1
# 2
# 3
# 5
# 8
# 13
# 21

# %% [markdown]
# # map(),Reduce(),Filter()

# %% [markdown]
# # map()
# The map() is a function it take two arguments.
# 1. A function
# 2. A sequence iterable.
# In the form of map(function,sequence)
#
# The first argument is the name of a function and the second a sequence (e.g. a list). map() applies the function to all the elements of the sequence. It returns a new list with the elements changed by the function.
#
# When we went over list comprehension we created a small expression to convert Fahrenheit to Celsius. Let's do the same here but use map. ons:
#
# - For every element present in the given sequence,apply some functionality and generate
# -
# new element with the required modification.  For this requirement we should go for
# map() function

# %%
# Withoiut lambda
l=[1,2,3,4,5]   
def doubleIt(x):
    return 2*x
l1=list(map(doubleIt,l))
print(l1)

# With Lambda
l=[1,2,3,4,5]   
l1=list(map(lambda x:2*x,l))   
print(l1)
# Out:
# [2, 4, 6, 8, 10]
# [2, 4, 6, 8, 10]

# %% [markdown]
# # reduce()
#
# reduce() function reduces sequence of elements into a single element by applying the
# specified function.
#
# reduce(function,sequence)
#
# reduce() function present in functools module and hence we should write imort
# stat
#
# If seq = [s1, s2, s3, ... , sn], calling reduce(function, sequence) works like this:
#
# * At first the first two elements of sequence will be applied to function, i.e. func(s1,s2)
# * The list on which reduce() works looks like this: [ function(s1, s2), s3, ... , sn ]
# * In the next step the function will be applied on the previous result and the third element of the list, i.e. function(function(s1, s2),s3)
# * The list looks like: [ function(function(s1, s2),s3), ... , sn ]
# * It continues like this until just one element is left and return this element as the result of reduce()ement.

# %%
from functools import *   
l=[10,20,30,40,50]
result=reduce(lambda x,y:x+y,l)
print(result)
# Out:
# 150

# %%
max_find =lambda a,b: a if(a>b) else b
lst=[47,49,55,69,10]

# %%
from functools import reduce
reduce(max_find,lst)
# Out:
# 69

# %% [markdown]
# map() can be applied to more than one iterable. The iterables must have the same length.
#
# For instance, if we are working with two lists-map() will apply its lambda function to the elements of the argument lists,
# i.e. it first applies to the elements with the 0th index, then to the elements with the 1st index until the nth index is reached.

# %% [markdown]
# # filter()
#
#  We can use filter() function to filter values from the given sequence based on some
# condition.
#
#  filter(function,sequence)
#   where function argument is responsible to perform conditionalk k
#   sequence can be list or tuple or string.

# %%
# without lambda function 
def isEven(x):
    if x%2==0:
        return True
    else:
        return False   
l=[0,5,10,15,20,25,30]   
l1=list(filter(isEven,l))   
print(l1) 

# with Lambda Function
l=[0,5,10,15,20,25,30]   
l1=list(filter(lambda x:x%2==0,l))   
print(l1)  
l2=list(filter(lambda x:x%2!=0,l))   
print(l2) #[5,15,25]
# Out:
# [0, 10, 20, 30]
# [0, 10, 20, 30]
# [5, 15, 25]

# %%
# create a function
def even_check(num):
    if num%2 ==0:
        return True
num=7
even_check(num)

# %% [markdown]
# Now lets filter list of numbers.Note that putting the function into filter without any parenthesis, but functions are objects as well

# %%
lst=[1,2,3,6,8,9,5]
list(filter(even_check,lst))
# Out:
# [2, 6, 8]

# %%
filter(even_check,lst)

# %% [markdown]
# filter() is more commonly used with lambda function, because we usally use filter for a quick job where we dont want to write an entire function. similar code using lambda function is below

# %%
list(map(lambda x: x%2==0,lst))
# Out:
# [False, True, False, True, True, False, False]

# %%
words=["hari","PythonProgram"," Code"]
long_words =list(filter(lambda word: len(word)>4, words))
print(long_words)
# Out:
# ['PythonProgram', ' Code']
